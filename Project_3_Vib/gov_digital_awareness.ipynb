# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/Users/vs/Desktop/Project_3/global_competitiveness_index_data.csv")
df.head()
# Out:
#   Country ISO3 Country Name  Indicator Id  \
# 0          AGO       Angola           495
# 1          AGO       Angola           496
# 2          AGO       Angola           507
# 3          AGO       Angola           508
# 4          AGO       Angola           509
#
#                                 Indicator Subindicator Type  2007-2008  \
# 0           GDP (PPP) as % of world total             Value        NaN
# 1           GDP (PPP) as % of world total              Rank        NaN
# 2          Imports as a percentage of GDP             Value        NaN
# 3          Imports as a percentage of GDP              Rank        NaN
# 4  Domestic market size index, 1-7 (best)             Value        NaN
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0        NaN        NaN   0.153000   0.145000        NaN   0.154000
# 1        NaN        NaN  62.000000  63.000000        NaN  63.000000
# 2        NaN        NaN  40.900000  54.127067        NaN  40.920500
# ...

# %%
df = pd.read_csv("/Users/vs/Desktop/Project_3/EGOV_DATA_2018.csv")
df.head()
# Out:
#      Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0           2018        Iraq                 155              0.3376
# 1           2018     Ireland                  22              0.8287
# 2           2018      Israel                  31              0.7998
# 3           2018       Italy                  24              0.8209
# 4           2018     Jamaica                 118              0.4697
# ..           ...          ...                ...                 ...
# 188         2018     Senegal                 150              0.3486
# 189         2018       Serbia                 49              0.7155
# 190         2018  Seychelles                  83              0.6163
# 191         2018   Singapore                   7              0.8812
# 192         2018    Slovakia                  49              0.7155
#
#      E-Participation Index  Online Service Index  Human Capital Index  \
# ...

# %%
df.describe()
# Out:
#        Survey Year  E-Government Rank  E-Government Index  \
# count        193.0         193.000000          193.000000
# mean        2018.0          96.989637            0.549064
# std            0.0          55.857425            0.212612
# min         2018.0           1.000000            0.056600
# 25%         2018.0          49.000000            0.375300
# 50%         2018.0          97.000000            0.561500
# 75%         2018.0         145.000000            0.715500
# max         2018.0         193.000000            0.915000
#
#        E-Participation Index  Online Service Index  Human Capital Index  \
# count             193.000000            193.000000           193.000000
# mean                0.565438              0.569084             0.662653
# std                 0.281593              0.268866             0.191503
# min                 0.000000              0.000000             0.000000
# 25%                 0.320200              0.326400             0.539700
# ...
