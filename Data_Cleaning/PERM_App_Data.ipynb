# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Resources/FY_CombinedData_Clean.csv')

# %%
data.head()
# Out:
#   Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE        CASE_STATUS  \
# 0       FY15           0  A-14220-96665    2015-02-03  Certified-Expired
# 1       FY15           1  A-14220-96720    2015-01-12  Certified-Expired
# 2       FY15           2  A-14203-91167    2014-12-18  Certified-Expired
# 3       FY15           3  A-14206-92509    2015-03-10  Certified-Expired
# 4       FY15           4  A-14202-90786    2015-01-07  Certified-Expired
#
#   CASE_RECEIVED_DATE               EMPLOYER_NAME  EMPLOYER_CITY  \
# 0         2014-09-10      UNION PACIFIC RAILROAD          OMAHA
# 1         2014-08-08          VST CONSULTING INC         ISELIN
# 2         2014-07-28                 GOOGLE INC.  MOUNTAIN VIEW
# 3         2014-10-19           INTEL CORPORATION    SANTA CLARA
# 4         2014-08-25  NET ESOLUTIONS CORPORATION         MCLEAN
#
#   EMPLOYER_STATE EMPLOYER_POSTAL_CODE  ...  FW_INFO_POSTAL_CODE  \
# 0       NEBRASKA                68179  ...                68154
# ...

# %%
data.count()
# Out:
# Unnamed: 0                       432819
# Unnamed: 1                       432819
# CASE_NUMBER                      432819
# DECISION_DATE                    432819
# CASE_STATUS                      432819
# CASE_RECEIVED_DATE               432817
# EMPLOYER_NAME                    432811
# EMPLOYER_CITY                    432808
# EMPLOYER_STATE                   432779
# EMPLOYER_POSTAL_CODE             432797
# EMPLOYER_NUM_EMPLOYEES           432672
# AGENT_FIRM_NAME                  380819
# AGENT_CITY                       389337
# AGENT_STATE                      381074
# PW_SOC_CODE                      432305
# PW_SOC_TITLE                     432305
# PW_AMOUNT_9089                   432609
# WAGE_OFFER_FROM_9089             432691
# WAGE_OFFER_UNIT_OF_PAY_9089      431535
# JOB_INFO_WORK_CITY               432728
# JOB_INFO_WORK_STATE              432726
# JOB_INFO_WORK_POSTAL_CODE        432690
# JOB_INFO_JOB_TITLE               432716
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'CASE_NUMBER', 'DECISION_DATE',
#        'CASE_STATUS', 'CASE_RECEIVED_DATE', 'EMPLOYER_NAME', 'EMPLOYER_CITY',
#        'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE', 'EMPLOYER_NUM_EMPLOYEES',
#        'AGENT_FIRM_NAME', 'AGENT_CITY', 'AGENT_STATE', 'PW_SOC_CODE',
#        'PW_SOC_TITLE', 'PW_AMOUNT_9089', 'WAGE_OFFER_FROM_9089',
#        'WAGE_OFFER_UNIT_OF_PAY_9089', 'JOB_INFO_WORK_CITY',
#        'JOB_INFO_WORK_STATE', 'JOB_INFO_WORK_POSTAL_CODE',
#        'JOB_INFO_JOB_TITLE', 'JOB_INFO_EDUCATION', 'JOB_INFO_EDUCATION_OTHER',
#        'FOREIGN_WORKER_INFO_CITY', 'FOREIGN_WORKER_INFO_STATE',
#        'FW_INFO_POSTAL_CODE', 'COUNTRY_OF_CITIZENSHIP',
#        'FW_INFO_BIRTH_COUNTRY', 'CLASS_OF_ADMISSION',
#        'FOREIGN_WORKER_INFO_EDUCATION', 'FW_INFO_EDUCATION_OTHER',
#        'DECISION_DATE_YEAR', 'DECISION_DATE_MONTH', 'CASE_RECEIVED_DATE_YEAR',
#        'CASE_RECEIVED_DATE_MONTH'],
#       dtype='object')

# %%
data2 = data[data.CASE_STATUS != 'Certified-Expired']
data3 = data2[data2.CASE_STATUS != 'Withdrawn']

# %%
data3['CASE_STATUS'].value_counts()
# Out:
# Certified    214239
# Denied        24227
# Name: CASE_STATUS, dtype: int64

# %%
data4 = data3.loc[data3['WAGE_OFFER_UNIT_OF_PAY_9089'] == 'Year']

# %%
data4['WAGE_OFFER_UNIT_OF_PAY_9089'].value_counts()
# Out:
# Year    228772
# Name: WAGE_OFFER_UNIT_OF_PAY_9089, dtype: int64

# %%
data4['EMPLOYER_ZIP_CODE'] = data4['EMPLOYER_POSTAL_CODE'].str[:5]
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data4.head()
# Out:
#    Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE CASE_STATUS  \
# 25       FY15          25  A-14246-03533    2015-06-22   Certified
# 28       FY15          28  A-14198-89806    2015-04-06   Certified
# 35       FY15          35  A-14222-96825    2015-06-24   Certified
# 61       FY15          61  A-13216-85505    2015-05-29   Certified
# 63       FY15          63  A-13179-76467    2015-04-20   Certified
#
#    CASE_RECEIVED_DATE                                  EMPLOYER_NAME  \
# 25         2014-12-19                           CITRIX SYSTEMS, INC.
# 28         2014-07-18  COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION
# 35         2014-12-11                              SAT SOLUTIONS LLC
# 61         2013-08-05                     KOCH FOODS OF ALABAMA, LLC
# 63         2013-06-28                                  FARROKH ERFAN
#
#       EMPLOYER_CITY EMPLOYER_STATE EMPLOYER_POSTAL_CODE  ...  \
# 25  FORT LAUDERDALE        FLORIDA                33309  ...
# ...

# %%
data4['COUNTRY_OF_CITIZENSHIP'] = data4['COUNTRY_OF_CITIZENSHIP'].str.upper()
data4['FW_INFO_BIRTH_COUNTRY'] = data4['FW_INFO_BIRTH_COUNTRY'].str.upper()
data4['EMPLOYER_NAME'] = data4['EMPLOYER_NAME'].str.upper()
data4['EMPLOYER_CITY'] = data4['EMPLOYER_CITY'].str.upper()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data4.head()
# Out:
#    Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE CASE_STATUS  \
# 25       FY15          25  A-14246-03533    2015-06-22   Certified
# 28       FY15          28  A-14198-89806    2015-04-06   Certified
# 35       FY15          35  A-14222-96825    2015-06-24   Certified
# 61       FY15          61  A-13216-85505    2015-05-29   Certified
# 63       FY15          63  A-13179-76467    2015-04-20   Certified
#
#    CASE_RECEIVED_DATE                                  EMPLOYER_NAME  \
# 25         2014-12-19                           CITRIX SYSTEMS, INC.
# 28         2014-07-18  COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION
# 35         2014-12-11                              SAT SOLUTIONS LLC
# 61         2013-08-05                     KOCH FOODS OF ALABAMA, LLC
# 63         2013-06-28                                  FARROKH ERFAN
#
#       EMPLOYER_CITY EMPLOYER_STATE EMPLOYER_POSTAL_CODE  ...  \
# 25  FORT LAUDERDALE        FLORIDA                33309  ...
# ...

# %%
data5 = data4[['CASE_STATUS', 
              'CASE_RECEIVED_DATE', 
              'DECISION_DATE', 
              'CLASS_OF_ADMISSION', 
              'FOREIGN_WORKER_INFO_EDUCATION', 
              'COUNTRY_OF_CITIZENSHIP',
              'FW_INFO_BIRTH_COUNTRY',
              'EMPLOYER_NAME',
              'EMPLOYER_CITY',
              'EMPLOYER_POSTAL_CODE',
              'EMPLOYER_STATE',
              'EMPLOYER_NUM_EMPLOYEES', 
              'WAGE_OFFER_UNIT_OF_PAY_9089',
              'DECISION_DATE_YEAR',
              'DECISION_DATE_MONTH',
              'CASE_RECEIVED_DATE_YEAR',
              'CASE_RECEIVED_DATE_MONTH',
              'WAGE_OFFER_FROM_9089']]

# %%
data5.head()
# Out:
#    CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE CLASS_OF_ADMISSION  \
# 25   Certified         2014-12-19    2015-06-22               H-1B
# 28   Certified         2014-07-18    2015-04-06               H-1B
# 35   Certified         2014-12-11    2015-06-24               H-1B
# 61   Certified         2013-08-05    2015-05-29                NaN
# 63   Certified         2013-06-28    2015-04-20                NaN
#
#    FOREIGN_WORKER_INFO_EDUCATION COUNTRY_OF_CITIZENSHIP FW_INFO_BIRTH_COUNTRY  \
# 25                      Master's                  CHINA                 CHINA
# 28                    Bachelor's                  INDIA                 INDIA
# 35                    Bachelor's                  INDIA                 INDIA
# 61                   Associate's                  CHINA                 CHINA
# 63                    Bachelor's                   IRAN                  IRAN
#
#                                     EMPLOYER_NAME    EMPLOYER_CITY  \
# ...

# %%
data5.dtypes
# Out:
# CASE_STATUS                       object
# CASE_RECEIVED_DATE                object
# DECISION_DATE                     object
# CLASS_OF_ADMISSION                object
# FOREIGN_WORKER_INFO_EDUCATION     object
# COUNTRY_OF_CITIZENSHIP            object
# FW_INFO_BIRTH_COUNTRY             object
# EMPLOYER_NAME                     object
# EMPLOYER_CITY                     object
# EMPLOYER_POSTAL_CODE              object
# EMPLOYER_STATE                    object
# EMPLOYER_NUM_EMPLOYEES           float64
# WAGE_OFFER_UNIT_OF_PAY_9089       object
# DECISION_DATE_YEAR                 int64
# DECISION_DATE_MONTH                int64
# CASE_RECEIVED_DATE_YEAR          float64
# CASE_RECEIVED_DATE_MONTH         float64
# WAGE_OFFER_FROM_9089             float64
# dtype: object

# %%
data5.to_excel('PERM_DIRTY.xlsx', index = False)

# %%
data6 = pd.read_csv('PERM_Data.csv')

# %%
data6.head()
# Out:
#   CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  DAYS_TIL_DECISION  \
# 0   Certified         2017-12-05    2018-04-24                140
# 1   Certified         2015-12-12    2016-06-02                173
# 2      Denied         2011-06-13    2017-04-20               2138
# 3   Certified         2016-07-14    2016-09-28                 76
# 4   Certified         2015-08-03    2016-04-21                262
#
#   CLASS_OF_ADMISSION FOREIGN_WORKER_INFO_EDUCATION COUNTRY_OF_CITIZENSHIP  \
# 0               H-1B                    Bachelor's                  INDIA
# 1               H-1B                   High School               MALAYSIA
# 2                E-3                         Other              AUSTRALIA
# 3               H-1B                    Bachelor's            PHILIPPINES
# 4               H-1B                    Bachelor's            PHILIPPINES
#
#   FW_INFO_BIRTH_COUNTRY                          EMPLOYER_NAME EMPLOYER_CITY  \
# ...

# %%
data6.count()
# Out:
# CASE_STATUS                      212839
# CASE_RECEIVED_DATE               212839
# DECISION_DATE                    212839
# DAYS_TIL_DECISION                212839
# CLASS_OF_ADMISSION               212839
# FOREIGN_WORKER_INFO_EDUCATION    212839
# COUNTRY_OF_CITIZENSHIP           212839
# FW_INFO_BIRTH_COUNTRY            212839
# EMPLOYER_NAME                    212839
# EMPLOYER_CITY                    212839
# EMPLOYER_STATE                   212839
# EMPLOYER_NUM_EMPLOYEES           212839
# WAGE_OFFER_UNIT_OF_PAY_9089      212839
# DECISION_DATE_YEAR               212839
# DECISION_DATE_MONTH              212839
# CASE_RECEIVED_DATE_YEAR          212839
# CASE_RECEIVED_DATE_MONTH         212839
# WAGE_OFFER_FROM_9089             212839
# EMPLOYER_ZIP_CODE                212839
# dtype: int64

# %%
data7 = data6.dropna(how='any')

# %%
data7.count()
# Out:
# CASE_STATUS                      212839
# CASE_RECEIVED_DATE               212839
# DECISION_DATE                    212839
# DAYS_TIL_DECISION                212839
# CLASS_OF_ADMISSION               212839
# FOREIGN_WORKER_INFO_EDUCATION    212839
# COUNTRY_OF_CITIZENSHIP           212839
# FW_INFO_BIRTH_COUNTRY            212839
# EMPLOYER_NAME                    212839
# EMPLOYER_CITY                    212839
# EMPLOYER_STATE                   212839
# EMPLOYER_NUM_EMPLOYEES           212839
# WAGE_OFFER_UNIT_OF_PAY_9089      212839
# DECISION_DATE_YEAR               212839
# DECISION_DATE_MONTH              212839
# CASE_RECEIVED_DATE_YEAR          212839
# CASE_RECEIVED_DATE_MONTH         212839
# WAGE_OFFER_FROM_9089             212839
# EMPLOYER_ZIP_CODE                212839
# dtype: int64

# %%
data7.dtypes
# Out:
# CASE_STATUS                       object
# CASE_RECEIVED_DATE                object
# DECISION_DATE                     object
# DAYS_TIL_DECISION                  int64
# CLASS_OF_ADMISSION                object
# FOREIGN_WORKER_INFO_EDUCATION     object
# COUNTRY_OF_CITIZENSHIP            object
# FW_INFO_BIRTH_COUNTRY             object
# EMPLOYER_NAME                     object
# EMPLOYER_CITY                     object
# EMPLOYER_STATE                    object
# EMPLOYER_NUM_EMPLOYEES             int64
# WAGE_OFFER_UNIT_OF_PAY_9089       object
# DECISION_DATE_YEAR                 int64
# DECISION_DATE_MONTH                int64
# CASE_RECEIVED_DATE_YEAR            int64
# CASE_RECEIVED_DATE_MONTH           int64
# WAGE_OFFER_FROM_9089             float64
# EMPLOYER_ZIP_CODE                  int64
# dtype: object

# %%
data7.head()
# Out:
#   CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  DAYS_TIL_DECISION  \
# 0   Certified         2017-12-05    2018-04-24                140
# 1   Certified         2015-12-12    2016-06-02                173
# 2      Denied         2011-06-13    2017-04-20               2138
# 3   Certified         2016-07-14    2016-09-28                 76
# 4   Certified         2015-08-03    2016-04-21                262
#
#   CLASS_OF_ADMISSION FOREIGN_WORKER_INFO_EDUCATION COUNTRY_OF_CITIZENSHIP  \
# 0               H-1B                    Bachelor's                  INDIA
# 1               H-1B                   High School               MALAYSIA
# 2                E-3                         Other              AUSTRALIA
# 3               H-1B                    Bachelor's            PHILIPPINES
# 4               H-1B                    Bachelor's            PHILIPPINES
#
#   FW_INFO_BIRTH_COUNTRY                          EMPLOYER_NAME EMPLOYER_CITY  \
# ...

# %%
data7.to_csv('../Resources/PERM_Data_Clean.csv', index = False)
