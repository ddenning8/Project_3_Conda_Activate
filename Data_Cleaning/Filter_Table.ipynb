# %%
import pandas as pd
import csv

# %%
f = open('../Resources/ML_Accuracy_Table.csv','r')

# %%
reader = csv.reader(f)

# %%
countries = {}

# %%
for row in reader:
    countries[row[0]] = {'country':row[0],'data':row[1],'training':row[2], 'testing':row[3]}

# %%
countries
# Out:
# {'\ufeffCountry': {'country': '\ufeffCountry',
#   'data': 'Data Count (Line 40)',
#   'training': 'Training Accuracy',
#   'testing': 'Testing Accuracy'},
#  'ARGENTINA': {'country': 'ARGENTINA',
#   'data': '697',
#   'training': '99.2',
#   'testing': '85.7'},
#  'ARMENIA': {'country': 'ARMENIA', 'data': '', 'training': '', 'testing': ''},
#  'AUSTRALIA': {'country': 'AUSTRALIA',
#   'data': '1260',
#   'training': '99.9',
#   'testing': '91.4'},
#  'AUSTRIA': {'country': 'AUSTRIA', 'data': '', 'training': '', 'testing': ''},
#  'BANGLADESH': {'country': 'BANGLADESH',
#   'data': '734',
#   'training': '98.9',
#   'testing': '88.6'},
#  'BELARUS': {'country': 'BELARUS',
#   'data': '335',
#   'training': '99.2',
#   'testing': '95.2'},
#  'BELGIUM': {'country': 'BELGIUM', 'data': '', 'training': '', 'testing': ''},
#  'BOLIVIA': {'country': 'BOLIVIA', 'data': '', 'training': '', 'testing': ''},
#  'BRAZIL': {'country': 'BRAZIL',
#   'data': '2272',
#   'training': '98.3',
# ...

# %%
countries['ARGENTINA']
# Out:
# {'country': 'ARGENTINA', 'data': '697', 'training': '99.2', 'testing': '85.7'}

# %%
countries['ARGENTINA']['training']
# Out:
# '99.2'
