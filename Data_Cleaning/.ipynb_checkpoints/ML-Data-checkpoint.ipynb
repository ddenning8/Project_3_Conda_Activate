# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Resources/GREEN_CARD_FULL.csv')

# %%
data.head()
# Out:
#          CASE_STATUS DECISION_DATE CASE_RECEIVED_DATE  DAYS_TIL_DECISION  \
# 0          CERTIFIED    2015-08-27         2015-02-02                206
# 1             DENIED    2015-03-20         2014-10-27                144
# 2          WITHDRAWN    2016-12-28         2016-12-12                 16
# 3  CERTIFIED-EXPIRED    2015-10-28         2015-04-13                198
# 4  CERTIFIED-EXPIRED    2014-10-14         2014-05-09                158
#
#                     EMPLOYER_NAME   EMPLOYER_CITY EMPLOYER_STATE  \
# 0                   DEUTSCHE BANK        NEW YORK       NEW YORK
# 1                    ENKITEC L.P.          IRVING          TEXAS
# 2               ZIONS BANK / ZMSC  SALT LAKE CITY           UTAH
# 3        XCEED TECHNOLOGIES, INC.    SOUTH RIDING       VIRGINIA
# 4  CENTRAL BUSINESS SOLUTIONS LLC          NEWARK     CALIFORNIA
#
#    EMPLOYER_ZIP_CODE  EMPLOYER_NUM_EMPLOYEES  PW_AMOUNT_9089  \
# 0              10005                 98000.0        220813.0
# 1              75038                    61.0         93870.0
# 2              84133                 10000.0         81536.0
# 3              20152                    64.0         91354.0
# 4              94560                    15.0         89502.0
#
#    WAGE_OFFER_FROM_9089 WAGE_OFFER_UNIT_OF_PAY_9089  \
# 0              950000.0                        Year
# 1              938000.0                        Year
# 2              930000.0                        Year
# 3              920000.0                        Year
# 4              889502.0                        Year
#
#                           JOB_INFO_JOB_TITLE JOB_INFO_EDUCATION  \
# 0  MANAGING DIRECTOR, FOREIGN EXCHANGE SALES           Master's
# 1                SENIOR TECHNICAL CONSULTANT         Bachelor's
# 2               INFORMATION SECURITY ANALYST           Master's
# 3                                RF ENGINEER           Master's
# 4                                QA ENGINEER           Master's
#
#    DECISION_DATE_YEAR  DECISION_DATE_MONTH  CASE_RECEIVED_DATE_YEAR  \
# 0                2015                    8                   2015.0
# 1                2015                    3                   2014.0
# 2                2016                   12                   2016.0
# 3                2015                   10                   2015.0
# 4                2014                   10                   2014.0
#
#    CASE_RECEIVED_DATE_MONTH COUNTRY_OF_CITIZENSHIP CLASS_OF_ADMISSION
# 0                       2.0            NETHERLANDS               H-1B
# 1                      10.0            PHILIPPINES               H-1B
# 2                      12.0                  INDIA               H-1B
# 3                       4.0                  INDIA               H-1B
# 4                       5.0                  INDIA               H-1B

# %%
data.count()
# Out:
# CASE_STATUS                    401771
# DECISION_DATE                  401771
# CASE_RECEIVED_DATE             401771
# DAYS_TIL_DECISION              401771
# EMPLOYER_NAME                  401771
# EMPLOYER_CITY                  401771
# EMPLOYER_STATE                 401771
# EMPLOYER_ZIP_CODE              401771
# EMPLOYER_NUM_EMPLOYEES         401771
# PW_AMOUNT_9089                 401771
# WAGE_OFFER_FROM_9089           401771
# WAGE_OFFER_UNIT_OF_PAY_9089    401771
# JOB_INFO_JOB_TITLE             401771
# JOB_INFO_EDUCATION             401771
# DECISION_DATE_YEAR             401771
# DECISION_DATE_MONTH            401771
# CASE_RECEIVED_DATE_YEAR        401771
# CASE_RECEIVED_DATE_MONTH       401771
# COUNTRY_OF_CITIZENSHIP         401771
# CLASS_OF_ADMISSION             401771
# dtype: int64

# %%
data['WAGE_OFFER_UNIT_OF_PAY_9089'].value_counts()
# Out:
# Year         389729
# Hour          11765
# Week            128
# Month           123
# Bi-Weekly        26
# Name: WAGE_OFFER_UNIT_OF_PAY_9089, dtype: int64

# %%
data2 = data[data.CASE_STATUS != 'CERTIFIED-EXPIRED']
data3 = data2[data2.CASE_STATUS != 'WITHDRAWN']

# %%
data3.head()
# Out:
#   CASE_STATUS DECISION_DATE CASE_RECEIVED_DATE  DAYS_TIL_DECISION  \
# 0   CERTIFIED    2015-08-27         2015-02-02                206
# 1      DENIED    2015-03-20         2014-10-27                144
# 5      DENIED    2015-09-25         2015-06-24                 93
# 8   CERTIFIED    2018-04-06         2017-11-06                151
# 9   CERTIFIED    2018-04-09         2017-11-21                139
#
#                           EMPLOYER_NAME  EMPLOYER_CITY EMPLOYER_STATE  \
# 0                         DEUTSCHE BANK       NEW YORK       NEW YORK
# 1                          ENKITEC L.P.         IRVING          TEXAS
# 5              MANILA SUNSET GRILL INC.  NATIONAL CITY     CALIFORNIA
# 8  MARIETTA HEALTH CARE PHYSICIANS, INC       MARIETTA           OHIO
# 9  MARIETTA HEALTH CARE PHYSICIANS, INC       MARIETTA           OHIO
#
#    EMPLOYER_ZIP_CODE  EMPLOYER_NUM_EMPLOYEES  PW_AMOUNT_9089  \
# 0              10005                 98000.0        220813.0
# 1              75038                    61.0         93870.0
# 5              91960                    29.0        885666.0
# 8              45750                   315.0        118477.0
# 9              45750                   315.0        118477.0
#
#    WAGE_OFFER_FROM_9089 WAGE_OFFER_UNIT_OF_PAY_9089  \
# 0              950000.0                        Year
# 1              938000.0                        Year
# 5              885666.0                        Year
# 8              800000.0                        Year
# 9              800000.0                        Year
#
#                           JOB_INFO_JOB_TITLE JOB_INFO_EDUCATION  \
# 0  MANAGING DIRECTOR, FOREIGN EXCHANGE SALES           Master's
# 1                SENIOR TECHNICAL CONSULTANT         Bachelor's
# 5                         GENERAL ACCOUNTANT         Bachelor's
# 8                               NEUROSURGEON              Other
# 9                               NEUROSURGEON              Other
#
#    DECISION_DATE_YEAR  DECISION_DATE_MONTH  CASE_RECEIVED_DATE_YEAR  \
# 0                2015                    8                   2015.0
# 1                2015                    3                   2014.0
# 5                2015                    9                   2015.0
# 8                2018                    4                   2017.0
# 9                2018                    4                   2017.0
#
#    CASE_RECEIVED_DATE_MONTH COUNTRY_OF_CITIZENSHIP CLASS_OF_ADMISSION
# 0                       2.0            NETHERLANDS               H-1B
# 1                      10.0            PHILIPPINES               H-1B
# 5                       6.0            PHILIPPINES               H-1B
# 8                      11.0                 CANADA               H-1B
# 9                      11.0                 GREECE               H-1B

# %%
data3['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED    201015
# DENIED        18802
# Name: CASE_STATUS, dtype: int64

# %%
data4 = data3[data.WAGE_OFFER_UNIT_OF_PAY_9089 == 'Year']
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
data4['WAGE_OFFER_UNIT_OF_PAY_9089'].value_counts()
# Out:
# Year    212979
# Name: WAGE_OFFER_UNIT_OF_PAY_9089, dtype: int64

# %%
data4.count()
# Out:
# CASE_STATUS                    212979
# DECISION_DATE                  212979
# CASE_RECEIVED_DATE             212979
# DAYS_TIL_DECISION              212979
# EMPLOYER_NAME                  212979
# EMPLOYER_CITY                  212979
# EMPLOYER_STATE                 212979
# EMPLOYER_ZIP_CODE              212979
# EMPLOYER_NUM_EMPLOYEES         212979
# PW_AMOUNT_9089                 212979
# WAGE_OFFER_FROM_9089           212979
# WAGE_OFFER_UNIT_OF_PAY_9089    212979
# JOB_INFO_JOB_TITLE             212979
# JOB_INFO_EDUCATION             212979
# DECISION_DATE_YEAR             212979
# DECISION_DATE_MONTH            212979
# CASE_RECEIVED_DATE_YEAR        212979
# CASE_RECEIVED_DATE_MONTH       212979
# COUNTRY_OF_CITIZENSHIP         212979
# CLASS_OF_ADMISSION             212979
# dtype: int64

# %%
data4.dtypes
# Out:
# CASE_STATUS                     object
# DECISION_DATE                   object
# CASE_RECEIVED_DATE              object
# DAYS_TIL_DECISION                int64
# EMPLOYER_NAME                   object
# EMPLOYER_CITY                   object
# EMPLOYER_STATE                  object
# EMPLOYER_ZIP_CODE                int64
# EMPLOYER_NUM_EMPLOYEES         float64
# PW_AMOUNT_9089                 float64
# WAGE_OFFER_FROM_9089           float64
# WAGE_OFFER_UNIT_OF_PAY_9089     object
# JOB_INFO_JOB_TITLE              object
# JOB_INFO_EDUCATION              object
# DECISION_DATE_YEAR               int64
# DECISION_DATE_MONTH              int64
# CASE_RECEIVED_DATE_YEAR        float64
# CASE_RECEIVED_DATE_MONTH       float64
# COUNTRY_OF_CITIZENSHIP          object
# CLASS_OF_ADMISSION              object
# EMPLOYER_STATE_REGION           object
# dtype: object

# %%
states = []

for row in data4['EMPLOYER_STATE']:
    if row == "MAINE":
        states.append("NORTHEAST")
    elif row == "NEW HAMPSHIRE":
        states.append("NORTHEAST")
    elif row == "VERMONT":
        states.append("NORTHEAST")
    elif row == "MASSACHUSETTS":
        states.append("NORTHEAST")
    elif row == "RHODE ISLAND":
        states.append("NORTHEAST")
    elif row == "CONNECTICUT":
        states.append("NORTHEAST")
    elif row == "NEW YORK":
        states.append("NORTHEAST")
    elif row == "NEW JERSEY":
        states.append("NORTHEAST")
    elif row == "PENNSYLVANIA":
        states.append("NORTHEAST")
    elif row == "DELAWARE":
        states.append("SOUTH")
    elif row == "MARYLAND":
        states.append("SOUTH")
    elif row == "DISTRICT OF COLUMBIA":
        states.append("SOUTH")
    elif row == "VIRGINIA":
        states.append("SOUTH")
    elif row == "WEST VIRGINIA":
        states.append("SOUTH")
    elif row == "NORTH CAROLINA":
        states.append("SOUTH")
    elif row == "SOUTH CAROLINA":
        states.append("SOUTH")
    elif row == "GEORGIA":
        states.append("SOUTH")
    elif row == "FLORIDA":
        states.append("SOUTH")
    elif row == "ALABAMA":
        states.append("SOUTH")
    elif row == "TENNESSE":
        states.append("SOUTH")
    elif row == "KENTUCKY":
        states.append("SOUTH")
    elif row == "OHIO":
        states.append("MIDWEST")
    elif row == "MICHIGAN":
        states.append("MIDWEST")
    elif row == "INDIANA":
        states.append("MIDWEST")
    elif row == "MISSISSIPPI":
        states.append("SOUTH")
    elif row == "ILLINOIS":
        states.append("MIDWEST")
    elif row == "WISCONSIN":
        states.append("MIDWEST")
    elif row == "MINNESOTA":
        states.append("MIDWEST")
    elif row == "IOWA":
        states.append("MIDWEST")
    elif row == "MISSOURI":
        states.append("MIDWEST")
    elif row == "ARKANSAS":
        states.append("SOUTH")
    elif row == "LOUISIANA":
        states.append("SOUTH")
    elif row == "NORTH DAKOTA":
        states.append("MIDWEST")
    elif row == "SOUTH DAKOTA":
        states.append("MIDWEST")
    elif row == "NEBRASKA":
        states.append("MIDWEST")
    elif row == "KANSAS":
        states.append("MIDWEST")
    elif row == "OKLAHOMA":
        states.append("SOUTH")
    elif row == "TEXAS":
        states.append("SOUTH")
    elif row == "MONTANA":
        states.append("WEST")
    elif row == "WYOMING":
        states.append("WEST")
    elif row == "COLORADO":
        states.append("WEST")
    elif row == "NEW MEXICO":
        states.append("WEST")
    elif row == "IDAHO":
        states.append("WEST")
    elif row == "UTAH":
        states.append("WEST")
    elif row == "ARIZONA":
        states.append("WEST")
    elif row == "WASHINGTON":
        states.append("WEST")
    elif row == "OREGON":
        states.append("WEST")
    elif row == "NEVADA":
        states.append("WEST")
    elif row == "CALIFORNIA":
        states.append("WEST")
    elif row == "ALASKA":
        states.append("WEST")
    elif row == "HAWAII":
        states.append("WEST")
    elif row == "PUERTO RICO":
        states.append("OTHER")
    elif row == "TENNESSEE":
        states.append("SOUTH")
    elif row == "NORTHERN MARIANA ISLANDS":
        states.append("OTHER")
    elif row == "VIRGIN ISLANDS":
        states.append("OTHER")
    elif row == "GUAM":
        states.append("OTHER")
    else:
        states.append("UNKNOWN")
        

data4['EMPLOYER_STATE_REGION'] = states
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data4.head()
# Out:
#   CASE_STATUS DECISION_DATE CASE_RECEIVED_DATE  DAYS_TIL_DECISION  \
# 0   CERTIFIED    2015-08-27         2015-02-02                206
# 1      DENIED    2015-03-20         2014-10-27                144
# 5      DENIED    2015-09-25         2015-06-24                 93
# 8   CERTIFIED    2018-04-06         2017-11-06                151
# 9   CERTIFIED    2018-04-09         2017-11-21                139
#
#                           EMPLOYER_NAME  EMPLOYER_CITY EMPLOYER_STATE  \
# 0                         DEUTSCHE BANK       NEW YORK       NEW YORK
# 1                          ENKITEC L.P.         IRVING          TEXAS
# 5              MANILA SUNSET GRILL INC.  NATIONAL CITY     CALIFORNIA
# 8  MARIETTA HEALTH CARE PHYSICIANS, INC       MARIETTA           OHIO
# 9  MARIETTA HEALTH CARE PHYSICIANS, INC       MARIETTA           OHIO
#
#    EMPLOYER_ZIP_CODE  EMPLOYER_NUM_EMPLOYEES  PW_AMOUNT_9089  ...  \
# 0              10005                 98000.0        220813.0  ...
# 1              75038                    61.0         93870.0  ...
# 5              91960                    29.0        885666.0  ...
# 8              45750                   315.0        118477.0  ...
# 9              45750                   315.0        118477.0  ...
#
#    WAGE_OFFER_UNIT_OF_PAY_9089                         JOB_INFO_JOB_TITLE  \
# 0                         Year  MANAGING DIRECTOR, FOREIGN EXCHANGE SALES
# 1                         Year                SENIOR TECHNICAL CONSULTANT
# 5                         Year                         GENERAL ACCOUNTANT
# 8                         Year                               NEUROSURGEON
# 9                         Year                               NEUROSURGEON
#
#   JOB_INFO_EDUCATION DECISION_DATE_YEAR  DECISION_DATE_MONTH  \
# 0           Master's               2015                    8
# 1         Bachelor's               2015                    3
# 5         Bachelor's               2015                    9
# 8              Other               2018                    4
# 9              Other               2018                    4
#
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  COUNTRY_OF_CITIZENSHIP  \
# 0                   2015.0                       2.0             NETHERLANDS
# 1                   2014.0                      10.0             PHILIPPINES
# 5                   2015.0                       6.0             PHILIPPINES
# 8                   2017.0                      11.0                  CANADA
# 9                   2017.0                      11.0                  GREECE
#
#   CLASS_OF_ADMISSION EMPLOYER_STATE_REGION
# 0               H-1B             NORTHEAST
# 1               H-1B                 SOUTH
# 5               H-1B                  WEST
# 8               H-1B               MIDWEST
# 9               H-1B               MIDWEST
#
# [5 rows x 21 columns]

# %%
data4['EMPLOYER_STATE_REGION'].value_counts()
# Out:
# WEST         76817
# SOUTH        57072
# NORTHEAST    49978
# MIDWEST      28837
# OTHER          275
# Name: EMPLOYER_STATE_REGION, dtype: int64

# %%
data4['EMPLOYER_STATE'].value_counts()
# Out:
# CALIFORNIA                  57641
# TEXAS                       24991
# NEW YORK                    16672
# NEW JERSEY                  15472
# WASHINGTON                  13210
# ILLINOIS                     9318
# MASSACHUSETTS                7622
# MICHIGAN                     7156
# PENNSYLVANIA                 7036
# FLORIDA                      6686
# VIRGINIA                     6026
# GEORGIA                      5439
# NORTH CAROLINA               4068
# OHIO                         3058
# MARYLAND                     2823
# CONNECTICUT                  2015
# MISSOURI                     1846
# MINNESOTA                    1776
# ARIZONA                      1731
# INDIANA                      1642
# WISCONSIN                    1623
# COLORADO                     1419
# KENTUCKY                      924
# TENNESSE                      919
# ALABAMA                       838
# DISTRICT OF COLUMBIA          746
# IOWA                          731
# ARKANSAS                      728
# KANSAS                        727
# OREGON                        685
# UTAH                          680
# SOUTH CAROLINA                655
# DELAWARE                      637
# LOUISIANA                     611
# NEBRASKA                      564
# RHODE ISLAND                  462
# OKLAHOMA                      455
# NEW MEXICO                    413
# NEVADA                        406
# NEW HAMPSHIRE                 319
# IDAHO                         289
# VERMONT                       227
# SOUTH DAKOTA                  222
# MISSISSIPPI                   194
# TENNESSEE                     190
# HAWAII                        182
# NORTH DAKOTA                  174
# MAINE                         153
# GUAM                          144
# WEST VIRGINIA                 142
# PUERTO RICO                    72
# MONTANA                        65
# ALASKA                         58
# WYOMING                        38
# VIRGIN ISLANDS                 32
# NORTHERN MARIANA ISLANDS       27
# Name: EMPLOYER_STATE, dtype: int64

# %%
data4.columns
# Out:
# Index(['CASE_STATUS', 'DECISION_DATE', 'CASE_RECEIVED_DATE',
#        'DAYS_TIL_DECISION', 'EMPLOYER_NAME', 'EMPLOYER_CITY', 'EMPLOYER_STATE',
#        'EMPLOYER_ZIP_CODE', 'EMPLOYER_NUM_EMPLOYEES', 'PW_AMOUNT_9089',
#        'WAGE_OFFER_FROM_9089', 'WAGE_OFFER_UNIT_OF_PAY_9089',
#        'JOB_INFO_JOB_TITLE', 'JOB_INFO_EDUCATION', 'DECISION_DATE_YEAR',
#        'DECISION_DATE_MONTH', 'CASE_RECEIVED_DATE_YEAR',
#        'CASE_RECEIVED_DATE_MONTH', 'COUNTRY_OF_CITIZENSHIP',
#        'CLASS_OF_ADMISSION', 'EMPLOYER_STATE_REGION'],
#       dtype='object')

# %%
data5 = data4[[
    'CASE_STATUS',
    'DAYS_TIL_DECISION',
    'EMPLOYER_NUM_EMPLOYEES',
    'WAGE_OFFER_FROM_9089',
    'JOB_INFO_EDUCATION',
    'CASE_RECEIVED_DATE_MONTH',
    'COUNTRY_OF_CITIZENSHIP',
    'CLASS_OF_ADMISSION',
    'EMPLOYER_STATE_REGION',
    'EMPLOYER_STATE'
]]

# %%
data5.head()
# Out:
#   CASE_STATUS  DAYS_TIL_DECISION  EMPLOYER_NUM_EMPLOYEES  \
# 0   CERTIFIED                206                 98000.0
# 1      DENIED                144                    61.0
# 5      DENIED                 93                    29.0
# 8   CERTIFIED                151                   315.0
# 9   CERTIFIED                139                   315.0
#
#    WAGE_OFFER_FROM_9089 JOB_INFO_EDUCATION  CASE_RECEIVED_DATE_MONTH  \
# 0              950000.0           Master's                       2.0
# 1              938000.0         Bachelor's                      10.0
# 5              885666.0         Bachelor's                       6.0
# 8              800000.0              Other                      11.0
# 9              800000.0              Other                      11.0
#
#   COUNTRY_OF_CITIZENSHIP CLASS_OF_ADMISSION EMPLOYER_STATE_REGION  \
# 0            NETHERLANDS               H-1B             NORTHEAST
# 1            PHILIPPINES               H-1B                 SOUTH
# 5            PHILIPPINES               H-1B                  WEST
# 8                 CANADA               H-1B               MIDWEST
# 9                 GREECE               H-1B               MIDWEST
#
#   EMPLOYER_STATE
# 0       NEW YORK
# 1          TEXAS
# 5     CALIFORNIA
# 8           OHIO
# 9           OHIO

# %%
data5.count()
# Out:
# CASE_STATUS                 212979
# DAYS_TIL_DECISION           212979
# EMPLOYER_NUM_EMPLOYEES      212979
# WAGE_OFFER_FROM_9089        212979
# JOB_INFO_EDUCATION          212979
# CASE_RECEIVED_DATE_MONTH    212979
# COUNTRY_OF_CITIZENSHIP      212979
# CLASS_OF_ADMISSION          212979
# EMPLOYER_STATE_REGION       212979
# EMPLOYER_STATE              212979
# dtype: int64

# %%
data6 = data5[[
    'DAYS_TIL_DECISION',
    'EMPLOYER_NUM_EMPLOYEES',
    'WAGE_OFFER_FROM_9089',
    'JOB_INFO_EDUCATION',
    'CASE_RECEIVED_DATE_MONTH',
    'COUNTRY_OF_CITIZENSHIP',
    'CLASS_OF_ADMISSION',
    'EMPLOYER_STATE_REGION',
    'CASE_STATUS'
]]

# %%
data6.head()
# Out:
#    DAYS_TIL_DECISION  EMPLOYER_NUM_EMPLOYEES  WAGE_OFFER_FROM_9089  \
# 0                206                 98000.0              950000.0
# 1                144                    61.0              938000.0
# 5                 93                    29.0              885666.0
# 8                151                   315.0              800000.0
# 9                139                   315.0              800000.0
#
#   JOB_INFO_EDUCATION  CASE_RECEIVED_DATE_MONTH COUNTRY_OF_CITIZENSHIP  \
# 0           Master's                       2.0            NETHERLANDS
# 1         Bachelor's                      10.0            PHILIPPINES
# 5         Bachelor's                       6.0            PHILIPPINES
# 8              Other                      11.0                 CANADA
# 9              Other                      11.0                 GREECE
#
#   CLASS_OF_ADMISSION EMPLOYER_STATE_REGION CASE_STATUS
# 0               H-1B             NORTHEAST   CERTIFIED
# 1               H-1B                 SOUTH      DENIED
# 5               H-1B                  WEST      DENIED
# 8               H-1B               MIDWEST   CERTIFIED
# 9               H-1B               MIDWEST   CERTIFIED

# %%
data6.to_csv('../Resources/ML_Data.csv', index = False)
