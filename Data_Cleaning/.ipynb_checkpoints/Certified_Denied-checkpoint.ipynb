# %%
import pandas as pd

# %%
data = pd.read_excel('FY_CombinedData_Clean.xlsx')

# %%
data.head()
# Out:
#   Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE        CASE_STATUS  \
# 0       FY15           0  A-14220-96665    2015-02-03  Certified-Expired
# 1        NaN           1  A-14220-96720    2015-01-12  Certified-Expired
# 2        NaN           2  A-14203-91167    2014-12-18  Certified-Expired
# 3        NaN           3  A-14206-92509    2015-03-10  Certified-Expired
# 4        NaN           4  A-14202-90786    2015-01-07  Certified-Expired
#
#   CASE_RECEIVED_DATE  DECISION_ELAPSED_DAYS  DECISION_ELAPSED_YEARS  \
# 0         2014-09-10                    146                0.400000
# 1         2014-08-08                    157                0.430137
# 2         2014-07-28                    143                0.391781
# 3         2014-10-19                    142                0.389041
# 4         2014-08-25                    135                0.369863
#
#                 EMPLOYER_NAME  EMPLOYER_CITY  ...  FW_INFO_POSTAL_CODE  \
# ...

# %%
data['CASE_STATUS'].value_counts()
# Out:
# Certified            214239
# Certified-Expired    177790
# Denied                24227
# Withdrawn             16563
# Name: CASE_STATUS, dtype: int64

# %%
data2 = data[data.CASE_STATUS != 'Certified-Expired']

# %%
data2.head()
# Out:
#    Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE CASE_STATUS  \
# 25        NaN          25  A-14246-03533    2015-06-22   Certified
# 28        NaN          28  A-14198-89806    2015-04-06   Certified
# 35        NaN          35  A-14222-96825    2015-06-24   Certified
# 61        NaN          61  A-13216-85505    2015-05-29   Certified
# 63        NaN          63  A-13179-76467    2015-04-20   Certified
#
#    CASE_RECEIVED_DATE  DECISION_ELAPSED_DAYS  DECISION_ELAPSED_YEARS  \
# 25         2014-12-19                    185                0.506849
# 28         2014-07-18                    262                0.717808
# 35         2014-12-11                    195                0.534247
# 61         2013-08-05                    662                1.813699
# 63         2013-06-28                    661                1.810959
#
#                                     EMPLOYER_NAME    EMPLOYER_CITY  ...  \
# ...

# %%
data2['CASE_STATUS'].value_counts()
# Out:
# Certified    214239
# Denied        24227
# Withdrawn     16563
# Name: CASE_STATUS, dtype: int64

# %%
data3 = data2[data2.CASE_STATUS != 'Withdrawn']
data3.head()
# Out:
#    Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE CASE_STATUS  \
# 25        NaN          25  A-14246-03533    2015-06-22   Certified
# 28        NaN          28  A-14198-89806    2015-04-06   Certified
# 35        NaN          35  A-14222-96825    2015-06-24   Certified
# 61        NaN          61  A-13216-85505    2015-05-29   Certified
# 63        NaN          63  A-13179-76467    2015-04-20   Certified
#
#    CASE_RECEIVED_DATE  DECISION_ELAPSED_DAYS  DECISION_ELAPSED_YEARS  \
# 25         2014-12-19                    185                0.506849
# 28         2014-07-18                    262                0.717808
# 35         2014-12-11                    195                0.534247
# 61         2013-08-05                    662                1.813699
# 63         2013-06-28                    661                1.810959
#
#                                     EMPLOYER_NAME    EMPLOYER_CITY  ...  \
# ...

# %%
data3['CASE_STATUS'].value_counts()
# Out:
# Certified    214239
# Denied        24227
# Name: CASE_STATUS, dtype: int64

# %%
data3.count()
# Out:
# Unnamed: 0                            0
# Unnamed: 1                       238466
# CASE_NUMBER                      238466
# DECISION_DATE                    238466
# CASE_STATUS                      238466
# CASE_RECEIVED_DATE               238466
# DECISION_ELAPSED_DAYS            238466
# DECISION_ELAPSED_YEARS           238466
# EMPLOYER_NAME                    238461
# EMPLOYER_CITY                    238458
# EMPLOYER_STATE                   238432
# EMPLOYER_POSTAL_CODE             238449
# EMPLOYER_NUM_EMPLOYEES           238332
# AGENT_FIRM_NAME                  209345
# AGENT_CITY                       214166
# AGENT_STATE                      209032
# PW_SOC_CODE                      237971
# PW_SOC_TITLE                     237971
# PW_AMOUNT_9089                   238262
# WAGE_OFFER_FROM_9089             238346
# WAGE_OFFER_UNIT_OF_PAY_9089      237539
# JOB_INFO_WORK_CITY               238386
# JOB_INFO_WORK_STATE              238384
# ...

# %%
data3.drop(['Unnamed: 0', 'Unnamed: 1'], axis=1)
# Out:
#           CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE  \
# 25      A-14246-03533    2015-06-22   Certified         2014-12-19
# 28      A-14198-89806    2015-04-06   Certified         2014-07-18
# 35      A-14222-96825    2015-06-24   Certified         2014-12-11
# 61      A-13216-85505    2015-05-29   Certified         2013-08-05
# 63      A-13179-76467    2015-04-20   Certified         2013-06-28
# 64      A-13213-84798    2015-04-06   Certified         2013-08-12
# 67      A-13305-09666    2015-06-25   Certified         2014-02-09
# 68      A-13304-09638    2015-05-06   Certified         2013-11-15
# 69      A-13304-09632    2015-06-08   Certified         2013-12-09
# 70      A-13305-09848    2015-06-11   Certified         2013-12-09
# 73      A-13305-09963    2015-05-14   Certified         2013-11-15
# 74      A-10180-06157    2015-09-02   Certified         2015-02-13
# 75      A-10302-28853    2015-05-29   Certified         2010-10-29
# ...

# %%
data3.to_csv('certified_denied.csv', index = False)
