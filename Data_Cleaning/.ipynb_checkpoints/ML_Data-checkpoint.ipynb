# %%
import pandas as pd

# %%
# Removed certified-expired and withdrawn entries. Only looking at h-1b greencard applications. only taking in yearly salary offers. need to clean up zipcode data (had random values) and dropped rows with null entries
data = pd.read_csv('../Resources/ml_data.csv')

# %%
data.head()
# Out:
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  DECISION_DATE_YEAR  \
# 0                     2017                        12                2018
# 1                     2014                        11                2015
# 2                     2015                         8                2016
# 3                     2016                         7                2016
# 4                     2015                         1                2015
#
#    DECISION_DATE_MONTH  DECISION_ELAPSED_DAYS  JOB_POSTAL_CODE  \
# 0                    4                    140          99901.0
# 1                    5                    172          99801.0
# 2                    4                    262          99801.0
# 3                    9                     76          99801.0
# 4                    8                    217          99776.0
#
#    WAGE_OFFER_FROM_9089  EMPLOYER_NUM_EMPLOYEES FOREIGN_WORKER_INFO_EDUCATION  \
# ...

# %%
data['CASE_STATUS'].value_counts()
# Out:
# Certified    151495
# Denied        10415
# Name: CASE_STATUS, dtype: int64

# %%
data['COUNTRY_OF_CITIZENSHIP'].value_counts()
# Out:
# INDIA                       109737
# CHINA                        16138
# CANADA                        4418
# SOUTH KOREA                   2976
# PHILIPPINES                   2085
# MEXICO                        1718
# TAIWAN                        1490
# UNITED KINGDOM                1375
# PAKISTAN                      1160
# NEPAL                         1095
# FRANCE                        1034
# TURKEY                         951
# BRAZIL                         896
# RUSSIA                         804
# JAPAN                          726
# VENEZUELA                      646
# GERMANY                        642
# IRAN                           587
# COLOMBIA                       583
# ITALY                          558
# UKRAINE                        520
# SPAIN                          490
# ISRAEL                         447
# NIGERIA                        445
# BANGLADESH                     423
# VIETNAM                        394
# ARGENTINA                      374
# ...

# %%
data['FOREIGN_WORKER_INFO_EDUCATION'].value_counts()
# Out:
# Master's       81841
# Bachelor's     62903
# Doctorate       8494
# Other           6631
# None            1154
# Associate's      573
# High School      229
# Name: FOREIGN_WORKER_INFO_EDUCATION, dtype: int64

# %%
data.dtypes
# Out:
# CASE_RECEIVED_DATE_YEAR            int64
# CASE_RECEIVED_DATE_MONTH           int64
# DECISION_DATE_YEAR                 int64
# DECISION_DATE_MONTH                int64
# DECISION_ELAPSED_DAYS              int64
# JOB_POSTAL_CODE                  float64
# WAGE_OFFER_FROM_9089             float64
# EMPLOYER_NUM_EMPLOYEES           float64
# FOREIGN_WORKER_INFO_EDUCATION     object
# COUNTRY_OF_CITIZENSHIP            object
# CASE_STATUS                       object
# dtype: object

# %%
data.count()
# Out:
# CASE_RECEIVED_DATE_YEAR          161910
# CASE_RECEIVED_DATE_MONTH         161910
# DECISION_DATE_YEAR               161910
# DECISION_DATE_MONTH              161910
# DECISION_ELAPSED_DAYS            161910
# JOB_POSTAL_CODE                  161906
# WAGE_OFFER_FROM_9089             161907
# EMPLOYER_NUM_EMPLOYEES           161899
# FOREIGN_WORKER_INFO_EDUCATION    161825
# COUNTRY_OF_CITIZENSHIP           161908
# CASE_STATUS                      161910
# dtype: int64

# %%
data2 = data.dropna()

# %%
data2.count()
# Out:
# CASE_RECEIVED_DATE_YEAR          161805
# CASE_RECEIVED_DATE_MONTH         161805
# DECISION_DATE_YEAR               161805
# DECISION_DATE_MONTH              161805
# DECISION_ELAPSED_DAYS            161805
# JOB_POSTAL_CODE                  161805
# WAGE_OFFER_FROM_9089             161805
# EMPLOYER_NUM_EMPLOYEES           161805
# FOREIGN_WORKER_INFO_EDUCATION    161805
# COUNTRY_OF_CITIZENSHIP           161805
# CASE_STATUS                      161805
# dtype: int64

# %%
data2['CASE_STATUS'].value_counts()
# Out:
# Certified    151493
# Denied        10312
# Name: CASE_STATUS, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb_make = LabelEncoder()
data2['COUNTRY_CODE'] = lb_make.fit_transform(data2['COUNTRY_OF_CITIZENSHIP'])
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2.head(20)
# Out:
#     CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  DECISION_DATE_YEAR  \
# 0                      2017                        12                2018
# 1                      2014                        11                2015
# 2                      2015                         8                2016
# 3                      2016                         7                2016
# 4                      2015                         1                2015
# 5                      2014                        11                2015
# 6                      2017                         6                2017
# 7                      2015                         1                2015
# 8                      2015                        10                2016
# 9                      2014                         5                2015
# 10                     2013                         8                2015
# 11                     2011                         9                2017
# ...

# %%
country_code = data2[['COUNTRY_OF_CITIZENSHIP', 'COUNTRY_CODE']]

# %%
country_code.head()
# Out:
#   COUNTRY_OF_CITIZENSHIP  COUNTRY_CODE
# 0                  INDIA            72
# 1              PALESTINE           122
# 2            PHILIPPINES           127
# 3            PHILIPPINES           127
# 4                  INDIA            72

# %%
country_code2 = country_code.groupby('COUNTRY_OF_CITIZENSHIP')['COUNTRY_CODE'].value_counts()

# %%
country_code3 = pd.DataFrame(data = country_code2)

# %%
country_code3
# Out:
#                                        COUNTRY_CODE
# COUNTRY_OF_CITIZENSHIP   COUNTRY_CODE
# AFGHANISTAN              0                        4
# ALBANIA                  1                       37
# ALGERIA                  2                       16
# ANDORRA                  3                        1
# ANGOLA                   4                        1
# ANTIGUA AND BARBUDA      5                        7
# ARGENTINA                6                      374
# ARMENIA                  7                       43
# AUSTRALIA                8                      322
# AUSTRIA                  9                       59
# AZERBAIJAN               10                      24
# BAHAMAS                  11                      47
# BAHRAIN                  12                       5
# BANGLADESH               13                     423
# BARBADOS                 14                      22
# BELARUS                  15                     100
# ...

# %%
mb_make = LabelEncoder()
data2['EDUCATION_CODE'] = mb_make.fit_transform(data2['FOREIGN_WORKER_INFO_EDUCATION'])
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2.head()
# Out:
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  DECISION_DATE_YEAR  \
# 0                     2017                        12                2018
# 1                     2014                        11                2015
# 2                     2015                         8                2016
# 3                     2016                         7                2016
# 4                     2015                         1                2015
#
#    DECISION_DATE_MONTH  DECISION_ELAPSED_DAYS  JOB_POSTAL_CODE  \
# 0                    4                    140          99901.0
# 1                    5                    172          99801.0
# 2                    4                    262          99801.0
# 3                    9                     76          99801.0
# 4                    8                    217          99776.0
#
#    WAGE_OFFER_FROM_9089  EMPLOYER_NUM_EMPLOYEES FOREIGN_WORKER_INFO_EDUCATION  \
# ...

# %%
education_code = data2[['FOREIGN_WORKER_INFO_EDUCATION', 'EDUCATION_CODE']]

# %%
education_code.head()
# Out:
#   FOREIGN_WORKER_INFO_EDUCATION  EDUCATION_CODE
# 0                    Bachelor's               1
# 1                    Bachelor's               1
# 2                    Bachelor's               1
# 3                    Bachelor's               1
# 4                     Doctorate               2

# %%
education_code2 = education_code.groupby('FOREIGN_WORKER_INFO_EDUCATION')['EDUCATION_CODE'].value_counts()

# %%
education_code2
# Out:
# FOREIGN_WORKER_INFO_EDUCATION  EDUCATION_CODE
# Associate's                    0                   573
# Bachelor's                     1                 62901
# Doctorate                      2                  8492
# High School                    3                   229
# Master's                       4                 81828
# None                           5                  1153
# Other                          6                  6629
# Name: EDUCATION_CODE, dtype: int64

# %%
data2.head()
# Out:
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  DECISION_DATE_YEAR  \
# 0                     2017                        12                2018
# 1                     2014                        11                2015
# 2                     2015                         8                2016
# 3                     2016                         7                2016
# 4                     2015                         1                2015
#
#    DECISION_DATE_MONTH  DECISION_ELAPSED_DAYS  JOB_POSTAL_CODE  \
# 0                    4                    140          99901.0
# 1                    5                    172          99801.0
# 2                    4                    262          99801.0
# 3                    9                     76          99801.0
# 4                    8                    217          99776.0
#
#    WAGE_OFFER_FROM_9089  EMPLOYER_NUM_EMPLOYEES FOREIGN_WORKER_INFO_EDUCATION  \
# ...

# %%
data3 = data2[['CASE_RECEIVED_DATE_YEAR', 
               'CASE_RECEIVED_DATE_MONTH', 
               'DECISION_DATE_YEAR', 
               'DECISION_DATE_MONTH', 
               'DECISION_ELAPSED_DAYS', 
               'JOB_POSTAL_CODE', 
               'WAGE_OFFER_FROM_9089', 
               'EMPLOYER_NUM_EMPLOYEES', 
               'COUNTRY_CODE', 
               'EDUCATION_CODE', 
               'CASE_STATUS']]

# %%
data4 = data2[['CASE_RECEIVED_DATE_MONTH',
               'DECISION_ELAPSED_DAYS', 
               'JOB_POSTAL_CODE', 
               'WAGE_OFFER_FROM_9089', 
               'EMPLOYER_NUM_EMPLOYEES', 
               'COUNTRY_CODE', 
               'EDUCATION_CODE', 
               'CASE_STATUS']]

# %%
data3.head()
# Out:
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH  DECISION_DATE_YEAR  \
# 0                     2017                        12                2018
# 1                     2014                        11                2015
# 2                     2015                         8                2016
# 3                     2016                         7                2016
# 4                     2015                         1                2015
#
#    DECISION_DATE_MONTH  DECISION_ELAPSED_DAYS  JOB_POSTAL_CODE  \
# 0                    4                    140          99901.0
# 1                    5                    172          99801.0
# 2                    4                    262          99801.0
# 3                    9                     76          99801.0
# 4                    8                    217          99776.0
#
#    WAGE_OFFER_FROM_9089  EMPLOYER_NUM_EMPLOYEES  COUNTRY_CODE  EDUCATION_CODE  \
# ...

# %%
data3.dtypes
# Out:
# CASE_RECEIVED_DATE_YEAR       int64
# CASE_RECEIVED_DATE_MONTH      int64
# DECISION_DATE_YEAR            int64
# DECISION_DATE_MONTH           int64
# DECISION_ELAPSED_DAYS         int64
# JOB_POSTAL_CODE             float64
# WAGE_OFFER_FROM_9089        float64
# EMPLOYER_NUM_EMPLOYEES      float64
# COUNTRY_CODE                  int64
# EDUCATION_CODE                int64
# CASE_STATUS                  object
# dtype: object

# %%
data4.head()
# Out:
#    CASE_RECEIVED_DATE_MONTH  DECISION_ELAPSED_DAYS  JOB_POSTAL_CODE  \
# 0                        12                    140          99901.0
# 1                        11                    172          99801.0
# 2                         8                    262          99801.0
# 3                         7                     76          99801.0
# 4                         1                    217          99776.0
#
#    WAGE_OFFER_FROM_9089  EMPLOYER_NUM_EMPLOYEES  COUNTRY_CODE  EDUCATION_CODE  \
# 0               61547.0                    40.0            72               1
# 1               58800.0                  1110.0           122               1
# 2               74692.0                   546.0           127               1
# 3               76981.0                   550.0           127               1
# 4              105333.0                  7439.0            72               2
#
#   CASE_STATUS
# 0   Certified
# 1   Certified
# 2   Certified
# 3   Certified
# ...

# %%
data4.dtypes
# Out:
# CASE_RECEIVED_DATE_MONTH      int64
# DECISION_ELAPSED_DAYS         int64
# JOB_POSTAL_CODE             float64
# WAGE_OFFER_FROM_9089        float64
# EMPLOYER_NUM_EMPLOYEES      float64
# COUNTRY_CODE                  int64
# EDUCATION_CODE                int64
# CASE_STATUS                  object
# dtype: object

# %%
from numpy.random import seed
seed(1)

# %%
import numpy as np
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
X = data4.drop("CASE_STATUS", axis=1)
y = data4["CASE_STATUS"]
print(X.shape, y.shape)
# Out:
# (161805, 7) (161805,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1, stratify=y)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=7))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
# Out:
# WARNING:tensorflow:From /anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# ...
# Total params: 11,102
# Trainable params: 11,102
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=10,
    shuffle=True,
    verbose=2
)
# Out:
# WARNING:tensorflow:From /anaconda3/envs/PythonData/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
#  - 11s - loss: 0.1604 - acc: 0.9527
# Epoch 2/10
#  - 11s - loss: 0.1475 - acc: 0.9544
# Epoch 3/10
#  - 11s - loss: 0.1417 - acc: 0.9538
# Epoch 4/10
#  - 11s - loss: 0.1366 - acc: 0.9545
# Epoch 5/10
#  - 11s - loss: 0.1303 - acc: 0.9570
# Epoch 6/10
#  - 11s - loss: 0.1241 - acc: 0.9605
# Epoch 7/10
#  - 11s - loss: 0.1185 - acc: 0.9623
# Epoch 8/10
#  - 11s - loss: 0.1149 - acc: 0.9633
# Epoch 9/10
#  - 11s - loss: 0.1120 - acc: 0.9651
# Epoch 10/10
#  - 11s - loss: 0.1102 - acc: 0.9662

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
#  - 1s - loss: 0.1115 - acc: 0.9662
# Normal Neural Network - Loss: 0.11145606801757554, Accuracy: 0.9662315845489502

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:20])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Predicted classes: ['Certified' 'Certified' 'Certified' 'Certified' 'Certified' 'Certified'
#  'Certified' 'Certified' 'Certified' 'Certified' 'Certified' 'Certified'
#  'Certified' 'Certified' 'Certified' 'Certified' 'Denied' 'Certified'
#  'Certified' 'Certified']
# Actual Labels: ['Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Certified', 'Denied', 'Certified', 'Certified', 'Certified']

# %%
data4['CASE_STATUS'].value_counts()
# Out:
# Certified    151493
# Denied        10312
# Name: CASE_STATUS, dtype: int64
