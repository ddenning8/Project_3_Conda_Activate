# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Resources/certified_denied.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 1    CASE_NUMBER DECISION_DATE CASE_STATUS  \
# 0         NaN          25  A-14246-03533    2015-06-22   Certified
# 1         NaN          28  A-14198-89806    2015-04-06   Certified
# 2         NaN          35  A-14222-96825    2015-06-24   Certified
# 3         NaN          61  A-13216-85505    2015-05-29   Certified
# 4         NaN          63  A-13179-76467    2015-04-20   Certified
#
#   CASE_RECEIVED_DATE  DECISION_ELAPSED_DAYS  DECISION_ELAPSED_YEARS  \
# 0         2014-12-19                    185                0.506849
# 1         2014-07-18                    262                0.717808
# 2         2014-12-11                    195                0.534247
# 3         2013-08-05                    662                1.813699
# 4         2013-06-28                    661                1.810959
#
#                                    EMPLOYER_NAME    EMPLOYER_CITY  \
# 0                           CITRIX SYSTEMS, INC.  FORT LAUDERDALE
# 1  COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION  COLLEGE STATION
# 2                              SAT SOLUTIONS LLC           MONROE
# 3                     KOCH FOODS OF ALABAMA, LLC       MONTGOMERY
# 4                                  FARROKH ERFAN     GAITHERSBURG
#
#              ...             FW_INFO_POSTAL_CODE COUNTRY_OF_CITIZENSHIP  \
# 0            ...             1973-03-30 00:00:00                  CHINA
# 1            ...                           75063                  INDIA
# 2            ...                           75001                  INDIA
# 3            ...                          210001                  CHINA
# 4            ...                             NaN                   IRAN
#
#    FW_INFO_BIRTH_COUNTRY CLASS_OF_ADMISSION FOREIGN_WORKER_INFO_EDUCATION  \
# 0                  CHINA               H-1B                      Master's
# 1                  INDIA               H-1B                    Bachelor's
# 2                  INDIA               H-1B                    Bachelor's
# 3                  CHINA                NaN                   Associate's
# 4                   IRAN                NaN                    Bachelor's
#
#   FW_INFO_EDUCATION_OTHER DECISION_DATE_YEAR DECISION_DATE_MONTH  \
# 0                     NaN               2015                   6
# 1                     NaN               2015                   4
# 2                     NaN               2015                   6
# 3                     NaN               2015                   5
# 4                     NaN               2015                   4
#
#    CASE_RECEIVED_DATE_YEAR  CASE_RECEIVED_DATE_MONTH
# 0                   2014.0                      12.0
# 1                   2014.0                       7.0
# 2                   2014.0                      12.0
# 3                   2013.0                       8.0
# 4                   2013.0                       6.0
#
# [5 rows x 39 columns]

# %%
data2 = data.loc[data['COUNTRY_OF_CITIZENSHIP'] == 'SWEDEN']

# %%
data2['COUNTRY_OF_CITIZENSHIP'].value_counts()
# Out:
# SWEDEN    278
# Name: COUNTRY_OF_CITIZENSHIP, dtype: int64

# %%
data3 = data2.loc[data2['WAGE_OFFER_UNIT_OF_PAY_9089'] == 'Year']

# %%
data3['WAGE_OFFER_UNIT_OF_PAY_9089'].value_counts()
# Out:
# Year    274
# Name: WAGE_OFFER_UNIT_OF_PAY_9089, dtype: int64

# %%
data3.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'CASE_NUMBER', 'DECISION_DATE',
#        'CASE_STATUS', 'CASE_RECEIVED_DATE', 'DECISION_ELAPSED_DAYS',
#        'DECISION_ELAPSED_YEARS', 'EMPLOYER_NAME', 'EMPLOYER_CITY',
#        'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE', 'EMPLOYER_NUM_EMPLOYEES',
#        'AGENT_FIRM_NAME', 'AGENT_CITY', 'AGENT_STATE', 'PW_SOC_CODE',
#        'PW_SOC_TITLE', 'PW_AMOUNT_9089', 'WAGE_OFFER_FROM_9089',
#        'WAGE_OFFER_UNIT_OF_PAY_9089', 'JOB_INFO_WORK_CITY',
#        'JOB_INFO_WORK_STATE', 'JOB_INFO_WORK_POSTAL_CODE',
#        'JOB_INFO_JOB_TITLE', 'JOB_INFO_EDUCATION', 'JOB_INFO_EDUCATION_OTHER',
#        'FOREIGN_WORKER_INFO_CITY', 'FOREIGN_WORKER_INFO_STATE',
#        'FW_INFO_POSTAL_CODE', 'COUNTRY_OF_CITIZENSHIP',
#        'FW_INFO_BIRTH_COUNTRY', 'CLASS_OF_ADMISSION',
#        'FOREIGN_WORKER_INFO_EDUCATION', 'FW_INFO_EDUCATION_OTHER',
#        'DECISION_DATE_YEAR', 'DECISION_DATE_MONTH', 'CASE_RECEIVED_DATE_YEAR',
#        'CASE_RECEIVED_DATE_MONTH'],
#       dtype='object')

# %%
data4 = data3[[
    'CASE_STATUS',
    'DECISION_ELAPSED_DAYS',
    'EMPLOYER_POSTAL_CODE',
    'EMPLOYER_STATE',
    'EMPLOYER_NUM_EMPLOYEES',
    'WAGE_OFFER_FROM_9089',
    'COUNTRY_OF_CITIZENSHIP',
    'CLASS_OF_ADMISSION',
    'FOREIGN_WORKER_INFO_EDUCATION',
    'CASE_RECEIVED_DATE_MONTH'
]]

# %%
data4.head()
# Out:
#      CASE_STATUS  DECISION_ELAPSED_DAYS EMPLOYER_POSTAL_CODE EMPLOYER_STATE  \
# 1227   Certified                    219                91201     CALIFORNIA
# 1272   Certified                    198                30188        GEORGIA
# 2876   Certified                    166                94404     CALIFORNIA
# 2998   Certified                    507                92675     CALIFORNIA
# 3219   Certified                    447                98052     WASHINGTON
#
#       EMPLOYER_NUM_EMPLOYEES  WAGE_OFFER_FROM_9089 COUNTRY_OF_CITIZENSHIP  \
# 1227                  1600.0              95943.67                 SWEDEN
# 1272                    12.0              54700.00                 SWEDEN
# 2876                   225.0             140039.00                 SWEDEN
# 2998                   140.0             172000.00                 SWEDEN
# 3219                 58000.0             133604.00                 SWEDEN
#
#      CLASS_OF_ADMISSION FOREIGN_WORKER_INFO_EDUCATION  \
# 1227               H-1B                      Master's
# 1272               H-1B                    Bachelor's
# 2876               H-1B                          None
# 2998               H-1B                   High School
# 3219                L-1                          None
#
#       CASE_RECEIVED_DATE_MONTH
# 1227                       9.0
# 1272                       2.0
# 2876                      11.0
# 2998                       3.0
# 3219                       6.0

# %%
states = []

for row in data4['EMPLOYER_STATE']:
    if row == "ME":
        states.append("MAINE")
    elif row == "NH":
        states.append("NEW HAMPSHIRE")
    elif row == "VT":
        states.append("VERMONT")
    elif row == "MA":
        states.append("MASSACHUSETTS")
    elif row == "RI":
        states.append("RHODE ISLAND")
    elif row == "CT":
        states.append("CONNECTICUT")
    elif row == "NY":
        states.append("NEW YORK")
    elif row == "NJ":
        states.append("NEW JERSEY")
    elif row == "PA":
        states.append("PENNSYLVANIA")
    elif row == "DE":
        states.append("DELAWARE")
    elif row == "MD":
        states.append("MARYLAND")
    elif row == "DC":
        states.append("DISTRICT OF COLUMBIA")
    elif row == "VA":
        states.append("VIRGINIA")
    elif row == "WV":
        states.append("WEST VIRGINIA")
    elif row == "NC":
        states.append("NORTH CAROLINA")
    elif row == "SC":
        states.append("SOUTH CAROLINA")
    elif row == "GA":
        states.append("GEORGIA")
    elif row == "FL":
        states.append("FLORIDA")
    elif row == "AL":
        states.append("ALABAMA")
    elif row == "TN":
        states.append("TENNESSEE")
    elif row == "TENNESSE":
        states.append("TENNESSEE")
    elif row == "KY":
        states.append("KENTUCKY")
    elif row == "OH":
        states.append("OHIO")
    elif row == "MI":
        states.append("MICHIGAN")
    elif row == "IN":
        states.append("INDIANA")
    elif row == "MS":
        states.append("MISSISSIPPI")
    elif row == "IL":
        states.append("ILLINOIS")
    elif row == "WI":
        states.append("WISCONSIN")
    elif row == "MN":
        states.append("MINNESOTA")
    elif row == "IA":
        states.append("IOWA")
    elif row == "MO":
        states.append("MISSOURI")
    elif row == "AR":
        states.append("ARKANSAS")
    elif row == "LA":
        states.append("LOUISIANA")
    elif row == "ND":
        states.append("NORTH DAKOTA")
    elif row == "SD":
        states.append("SOUTH DAKOTA")
    elif row == "NE":
        states.append("NEBRASKA")
    elif row == "KS":
        states.append("KANSAS")
    elif row == "OK":
        states.append("OKLAHOMA")
    elif row == "TX":
        states.append("TEXAS")
    elif row == "MT":
        states.append("MONTANA")
    elif row == "WY":
        states.append("WYOMING")
    elif row == "CO":
        states.append("COLORADO")
    elif row == "NM":
        states.append("NEW MEXICO")
    elif row == "ID":
        states.append("IDAHO")
    elif row == "UT":
        states.append("UTAH")
    elif row == "AZ":
        states.append("ARIZONA")
    elif row == "WA":
        states.append("WASHINGTON")
    elif row == "OR":
        states.append("OREGON")
    elif row == "NV":
        states.append("NEVADA")
    elif row == "CA":
        states.append("CALIFORNIA")
    elif row == "AK":
        states.append("ALASKA")
    elif row == "HI":
        states.append("HAWAII")
    elif row == "PR":
        states.append("PUERTO RICO")
    elif row == "MP":
        states.append("NORTHERN MARIANA ISLANDS")
    elif row == "VI":
        states.append("VIRGIN ISLANDS")
    elif row == "GU":
        states.append("GUAM")
    elif row == "NEW HAMPSHIRE":
        states.append("NEW HAMPSHIRE")
    elif row == "VERMONT":
        states.append("VERMONT")
    elif row == "MASSACHUSETTS":
        states.append("MASSACHUSETTS")
    elif row == "RHODE ISLAND":
        states.append("RHODE ISLAND")
    elif row == "CONNECTICUT":
        states.append("CONNECTICUT")
    elif row == "NEW YORK":
        states.append("NEW YORK")
    elif row == "NEW JERSEY":
        states.append("NEW JERSEY")
    elif row == "PENNSYLVANIA":
        states.append("PENNSYLVANIA")
    elif row == "DELAWARE":
        states.append("DELAWARE")
    elif row == "MARYLAND":
        states.append("MARYLAND")
    elif row == "DISTRICT OF COLUMBIA":
        states.append("DISTRICT OF COLUMBIA")
    elif row == "VIRGINIA":
        states.append("VIRGINIA")
    elif row == "WEST VIRGINIA":
        states.append("WEST VIRGINIA")
    elif row == "NORTH CAROLINA":
        states.append("NORTH CAROLINA")
    elif row == "SOUTH CAROLINA":
        states.append("SOUTH CAROLINA")
    elif row == "GEORGIA":
        states.append("GEORGIA")
    elif row == "FLORIDA":
        states.append("FLORIDA")
    elif row == "ALABAMA":
        states.append("ALABAMA")
    elif row == "TENNESSEE":
        states.append("TENNESSEE")
    elif row == "TENNESSEE":
        states.append("TENNESSEE")
    elif row == "KENTUCKY":
        states.append("KENTUCKY")
    elif row == "OHIO":
        states.append("OHIO")
    elif row == "MICHIGAN":
        states.append("MICHIGAN")
    elif row == "INDIANA":
        states.append("INDIANA")
    elif row == "MISSISSIPPI":
        states.append("MISSISSIPPI")
    elif row == "ILLINOIS":
        states.append("ILLINOIS")
    elif row == "WISCONSIN":
        states.append("WISCONSIN")
    elif row == "MINNESOTA":
        states.append("MINNESOTA")
    elif row == "IOWA":
        states.append("IOWA")
    elif row == "MISSOURI":
        states.append("MISSOURI")
    elif row == "ARKANSAS":
        states.append("ARKANSAS")
    elif row == "LOUISIANA":
        states.append("LOUISIANA")
    elif row == "NORTH DAKOTA":
        states.append("NORTH DAKOTA")
    elif row == "SOUTH DAKOTA":
        states.append("SOUTH DAKOTA")
    elif row == "NEBRASKA":
        states.append("NEBRASKA")
    elif row == "KANSAS":
        states.append("KANSAS")
    elif row == "OKLAHOMA":
        states.append("OKLAHOMA")
    elif row == "TEXAS":
        states.append("TEXAS")
    elif row == "MONTANA":
        states.append("MONTANA")
    elif row == "WYOMING":
        states.append("WYOMING")
    elif row == "COLORADO":
        states.append("COLORADO")
    elif row == "NEW MEXICO":
        states.append("NEW MEXICO")
    elif row == "IDAHO":
        states.append("IDAHO")
    elif row == "UTAH":
        states.append("UTAH")
    elif row == "ARIZONA":
        states.append("ARIZONA")
    elif row == "WASHINGTON":
        states.append("WASHINGTON")
    elif row == "OREGON":
        states.append("OREGON")
    elif row == "NEVADA":
        states.append("NEVADA")
    elif row == "CALIFORNIA":
        states.append("CALIFORNIA")
    elif row == "ALASKA":
        states.append("ALASKA")
    elif row == "HAWAII":
        states.append("HAWAII")
    elif row == "PUERTO RICO":
        states.append("PUERTO RICO")
    elif row == "NORTHERN MARIANA ISLANDS":
        states.append("NORTHERN MARIANA ISLANDS")
    elif row == "VIRGIN ISLANDS":
        states.append("VIRGIN ISLANDS")
    elif row == "GUAM":
        states.append("GUAM")
    else:
        states.append("UNKNOWN")
        
data4['EMPLOYER_STATES'] = states
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data4['EMPLOYER_STATES'].value_counts()
# Out:
# CALIFORNIA              112
# NEW YORK                 40
# WASHINGTON               19
# FLORIDA                  12
# NEW JERSEY               11
# MASSACHUSETTS            11
# NORTH CAROLINA           11
# TEXAS                    11
# ILLINOIS                  7
# CONNECTICUT               7
# GEORGIA                   6
# MICHIGAN                  4
# PENNSYLVANIA              3
# MINNESOTA                 2
# WISCONSIN                 2
# NEVADA                    2
# UTAH                      2
# RHODE ISLAND              1
# MISSOURI                  1
# ARIZONA                   1
# OREGON                    1
# ARKANSAS                  1
# COLORADO                  1
# MARYLAND                  1
# KENTUCKY                  1
# INDIANA                   1
# TENNESSEE                 1
# OHIO                      1
# DISTRICT OF COLUMBIA      1
# Name: EMPLOYER_STATES, dtype: int64

# %%
data5 = data4.dropna(how='any')

# %%
data5.head()
# Out:
#      CASE_STATUS  DECISION_ELAPSED_DAYS EMPLOYER_POSTAL_CODE EMPLOYER_STATE  \
# 1227   Certified                    219                91201     CALIFORNIA
# 1272   Certified                    198                30188        GEORGIA
# 2876   Certified                    166                94404     CALIFORNIA
# 2998   Certified                    507                92675     CALIFORNIA
# 3219   Certified                    447                98052     WASHINGTON
#
#       EMPLOYER_NUM_EMPLOYEES  WAGE_OFFER_FROM_9089 COUNTRY_OF_CITIZENSHIP  \
# 1227                  1600.0              95943.67                 SWEDEN
# 1272                    12.0              54700.00                 SWEDEN
# 2876                   225.0             140039.00                 SWEDEN
# 2998                   140.0             172000.00                 SWEDEN
# 3219                 58000.0             133604.00                 SWEDEN
#
#      CLASS_OF_ADMISSION FOREIGN_WORKER_INFO_EDUCATION  \
# 1227               H-1B                      Master's
# 1272               H-1B                    Bachelor's
# 2876               H-1B                          None
# 2998               H-1B                   High School
# 3219                L-1                          None
#
#       CASE_RECEIVED_DATE_MONTH EMPLOYER_STATES
# 1227                       9.0      CALIFORNIA
# 1272                       2.0         GEORGIA
# 2876                      11.0      CALIFORNIA
# 2998                       3.0      CALIFORNIA
# 3219                       6.0      WASHINGTON

# %%
states = []

for row in data5['EMPLOYER_STATES']:
    if row == "MAINE":
        states.append("NORTHEAST")
    elif row == "NEW HAMPSHIRE":
        states.append("NORTHEAST")
    elif row == "VERMONT":
        states.append("NORTHEAST")
    elif row == "MASSACHUSETTS":
        states.append("NORTHEAST")
    elif row == "RHODE ISLAND":
        states.append("NORTHEAST")
    elif row == "CONNECTICUT":
        states.append("NORTHEAST")
    elif row == "NEW YORK":
        states.append("NORTHEAST")
    elif row == "NEW JERSEY":
        states.append("NORTHEAST")
    elif row == "PENNSYLVANIA":
        states.append("NORTHEAST")
    elif row == "DELAWARE":
        states.append("SOUTH")
    elif row == "MARYLAND":
        states.append("SOUTH")
    elif row == "DISTRICT OF COLUMBIA":
        states.append("SOUTH")
    elif row == "VIRGINIA":
        states.append("SOUTH")
    elif row == "WEST VIRGINIA":
        states.append("SOUTH")
    elif row == "NORTH CAROLINA":
        states.append("SOUTH")
    elif row == "SOUTH CAROLINA":
        states.append("SOUTH")
    elif row == "GEORGIA":
        states.append("SOUTH")
    elif row == "FLORIDA":
        states.append("SOUTH")
    elif row == "ALABAMA":
        states.append("SOUTH")
    elif row == "TENNESSE":
        states.append("SOUTH")
    elif row == "KENTUCKY":
        states.append("SOUTH")
    elif row == "OHIO":
        states.append("MIDWEST")
    elif row == "MICHIGAN":
        states.append("MIDWEST")
    elif row == "INDIANA":
        states.append("MIDWEST")
    elif row == "MISSISSIPPI":
        states.append("SOUTH")
    elif row == "ILLINOIS":
        states.append("MIDWEST")
    elif row == "WISCONSIN":
        states.append("MIDWEST")
    elif row == "MINNESOTA":
        states.append("MIDWEST")
    elif row == "IOWA":
        states.append("MIDWEST")
    elif row == "MISSOURI":
        states.append("MIDWEST")
    elif row == "ARKANSAS":
        states.append("SOUTH")
    elif row == "LOUISIANA":
        states.append("SOUTH")
    elif row == "NORTH DAKOTA":
        states.append("MIDWEST")
    elif row == "SOUTH DAKOTA":
        states.append("MIDWEST")
    elif row == "NEBRASKA":
        states.append("MIDWEST")
    elif row == "KANSAS":
        states.append("MIDWEST")
    elif row == "OKLAHOMA":
        states.append("SOUTH")
    elif row == "TEXAS":
        states.append("SOUTH")
    elif row == "MONTANA":
        states.append("WEST")
    elif row == "WYOMING":
        states.append("WEST")
    elif row == "COLORADO":
        states.append("WEST")
    elif row == "NEW MEXICO":
        states.append("WEST")
    elif row == "IDAHO":
        states.append("WEST")
    elif row == "UTAH":
        states.append("WEST")
    elif row == "ARIZONA":
        states.append("WEST")
    elif row == "WASHINGTON":
        states.append("WEST")
    elif row == "OREGON":
        states.append("WEST")
    elif row == "NEVADA":
        states.append("WEST")
    elif row == "CALIFORNIA":
        states.append("WEST")
    elif row == "ALASKA":
        states.append("WEST")
    elif row == "HAWAII":
        states.append("WEST")
    elif row == "PUERTO RICO":
        states.append("OTHER")
    elif row == "TENNESSEE":
        states.append("SOUTH")
    elif row == "NORTHERN MARIANA ISLANDS":
        states.append("OTHER")
    elif row == "VIRGIN ISLANDS":
        states.append("OTHER")
    elif row == "GUAM":
        states.append("OTHER")
    else:
        states.append("UNKNOWN")
        
data5['EMPLOYER_REGIONS'] = states
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data5['EMPLOYER_REGIONS'].value_counts()
# Out:
# WEST         131
# NORTHEAST     72
# SOUTH         41
# MIDWEST       16
# Name: EMPLOYER_REGIONS, dtype: int64

# %%
data5.count()
# Out:
# CASE_STATUS                      260
# DECISION_ELAPSED_DAYS            260
# EMPLOYER_POSTAL_CODE             260
# EMPLOYER_STATE                   260
# EMPLOYER_NUM_EMPLOYEES           260
# WAGE_OFFER_FROM_9089             260
# COUNTRY_OF_CITIZENSHIP           260
# CLASS_OF_ADMISSION               260
# FOREIGN_WORKER_INFO_EDUCATION    260
# CASE_RECEIVED_DATE_MONTH         260
# EMPLOYER_STATES                  260
# EMPLOYER_REGIONS                 260
# dtype: int64

# %%
data5['DAY_BINS'] = pd.cut(x=data5['DECISION_ELAPSED_DAYS'], 
                             bins=[0, 90, 180, 365, 3600],
                           labels=['0-90', '91-180', '181-365', '366-3600'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data5['DAY_BINS'].value_counts()
# Out:
# 91-180      107
# 0-90         85
# 181-365      46
# 366-3600     21
# Name: DAY_BINS, dtype: int64

# %%
data5['WAGE_BINS'] = pd.cut(x=data5['WAGE_OFFER_FROM_9089'], 
                             bins=[0, 25000, 50000, 75000, 100000, 500000],
                           labels=['0-25000', '25001-50000', '50001-75000', '75001-100000', '100000-500000'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data5['WAGE_BINS'].value_counts()
# Out:
# 100000-500000    187
# 75001-100000      39
# 50001-75000       21
# 25001-50000       13
# 0-25000            0
# Name: WAGE_BINS, dtype: int64

# %%
data5['EMPLOYEE_BINS'] = pd.cut(x=data5['EMPLOYER_NUM_EMPLOYEES'], 
                             bins=[0, 50, 100, 500, 1000, 10000, 1000000000],
                           labels=['0-50', '51-100', '101-500', '501-1000', '1001-10000', '10001-1000000000'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data5['EMPLOYEE_BINS'].value_counts()
# Out:
# 10001-1000000000    92
# 1001-10000          52
# 0-50                50
# 101-500             29
# 51-100              19
# 501-1000            18
# Name: EMPLOYEE_BINS, dtype: int64

# %%
data5.count()
# Out:
# CASE_STATUS                      260
# DECISION_ELAPSED_DAYS            260
# EMPLOYER_POSTAL_CODE             260
# EMPLOYER_STATE                   260
# EMPLOYER_NUM_EMPLOYEES           260
# WAGE_OFFER_FROM_9089             260
# COUNTRY_OF_CITIZENSHIP           260
# CLASS_OF_ADMISSION               260
# FOREIGN_WORKER_INFO_EDUCATION    260
# CASE_RECEIVED_DATE_MONTH         260
# EMPLOYER_STATES                  260
# EMPLOYER_REGIONS                 260
# DAY_BINS                         259
# WAGE_BINS                        260
# EMPLOYEE_BINS                    260
# dtype: int64

# %%
data6 = data5[[
    'CASE_STATUS',
    'EMPLOYEE_BINS',
    'WAGE_BINS',
    'EMPLOYER_REGIONS',
    'CASE_RECEIVED_DATE_MONTH',
    'FOREIGN_WORKER_INFO_EDUCATION',
    'CLASS_OF_ADMISSION',
    'DAY_BINS'
]]

# %%
data6.head()
# Out:
#      CASE_STATUS     EMPLOYEE_BINS      WAGE_BINS EMPLOYER_REGIONS  \
# 1227   Certified        1001-10000   75001-100000             WEST
# 1272   Certified              0-50    50001-75000            SOUTH
# 2876   Certified           101-500  100000-500000             WEST
# 2998   Certified           101-500  100000-500000             WEST
# 3219   Certified  10001-1000000000  100000-500000             WEST
#
#       CASE_RECEIVED_DATE_MONTH FOREIGN_WORKER_INFO_EDUCATION  \
# 1227                       9.0                      Master's
# 1272                       2.0                    Bachelor's
# 2876                      11.0                          None
# 2998                       3.0                   High School
# 3219                       6.0                          None
#
#      CLASS_OF_ADMISSION  DAY_BINS
# 1227               H-1B   181-365
# 1272               H-1B   181-365
# 2876               H-1B    91-180
# 2998               H-1B  366-3600
# 3219                L-1  366-3600

# %%
data6.dtypes
# Out:
# CASE_STATUS                        object
# EMPLOYEE_BINS                    category
# WAGE_BINS                        category
# EMPLOYER_REGIONS                   object
# CASE_RECEIVED_DATE_MONTH          float64
# FOREIGN_WORKER_INFO_EDUCATION      object
# CLASS_OF_ADMISSION                 object
# DAY_BINS                         category
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
num_encode = LabelEncoder()

# %%
data6['CLASS_OF_ADMISSION_CODE'] = num_encode.fit_transform(data6['CLASS_OF_ADMISSION'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['FOREIGN_WORKER_INFO_EDUCATION_CODE'] = num_encode.fit_transform(data6['FOREIGN_WORKER_INFO_EDUCATION'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['WAGE_BINS'] = data6['WAGE_BINS'].astype(str)
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['WAGE_BINS_CODE'] = num_encode.fit_transform(data6['WAGE_BINS'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['EMPLOYER_REGIONS_CODE'] = num_encode.fit_transform(data6['EMPLOYER_REGIONS'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['DAY_BINS'] = data6['DAY_BINS'].astype(str)
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['DAY_BINS_CODE'] = num_encode.fit_transform(data6['DAY_BINS'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['EMPLOYEE_BINS'] = data6['EMPLOYEE_BINS'].astype(str)
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6['EMPLOYEE_BINS_CODE'] = num_encode.fit_transform(data6['EMPLOYEE_BINS'])
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data6.head()
# Out:
#      CASE_STATUS     EMPLOYEE_BINS      WAGE_BINS EMPLOYER_REGIONS  \
# 1227   Certified        1001-10000   75001-100000             WEST
# 1272   Certified              0-50    50001-75000            SOUTH
# 2876   Certified           101-500  100000-500000             WEST
# 2998   Certified           101-500  100000-500000             WEST
# 3219   Certified  10001-1000000000  100000-500000             WEST
#
#       CASE_RECEIVED_DATE_MONTH FOREIGN_WORKER_INFO_EDUCATION  \
# 1227                       9.0                      Master's
# 1272                       2.0                    Bachelor's
# 2876                      11.0                          None
# 2998                       3.0                   High School
# 3219                       6.0                          None
#
#      CLASS_OF_ADMISSION  DAY_BINS  CLASS_OF_ADMISSION_CODE  \
# 1227               H-1B   181-365                        3
# 1272               H-1B   181-365                        3
# 2876               H-1B    91-180                        3
# 2998               H-1B  366-3600                        3
# 3219                L-1  366-3600                        5
#
#       FOREIGN_WORKER_INFO_EDUCATION_CODE  WAGE_BINS_CODE  \
# 1227                                   4               3
# 1272                                   1               2
# 2876                                   5               0
# 2998                                   3               0
# 3219                                   5               0
#
#       EMPLOYER_REGIONS_CODE  DAY_BINS_CODE  EMPLOYEE_BINS_CODE
# 1227                      3              1                   2
# 1272                      2              1                   0
# 2876                      3              3                   3
# 2998                      3              2                   3
# 3219                      3              2                   1

# %%
# data7.to_excel('../Resources/ML2_Philippenes.xlsx', index = False)

# %%
data6.count()
# Out:
# CASE_STATUS                           260
# EMPLOYEE_BINS                         260
# WAGE_BINS                             260
# EMPLOYER_REGIONS                      260
# CASE_RECEIVED_DATE_MONTH              260
# FOREIGN_WORKER_INFO_EDUCATION         260
# CLASS_OF_ADMISSION                    260
# DAY_BINS                              260
# CLASS_OF_ADMISSION_CODE               260
# FOREIGN_WORKER_INFO_EDUCATION_CODE    260
# WAGE_BINS_CODE                        260
# EMPLOYER_REGIONS_CODE                 260
# DAY_BINS_CODE                         260
# EMPLOYEE_BINS_CODE                    260
# dtype: int64

# %%
data7 = data6[[
    'CASE_STATUS',
    'EMPLOYEE_BINS_CODE',
    'WAGE_BINS_CODE',
    'DAY_BINS_CODE',
    'FOREIGN_WORKER_INFO_EDUCATION_CODE',
    'CLASS_OF_ADMISSION_CODE',
    'CASE_RECEIVED_DATE_MONTH',
    'EMPLOYER_REGIONS_CODE'
]]

# %%
data7.head()
# Out:
#      CASE_STATUS  EMPLOYEE_BINS_CODE  WAGE_BINS_CODE  DAY_BINS_CODE  \
# 1227   Certified                   2               3              1
# 1272   Certified                   0               2              1
# 2876   Certified                   3               0              3
# 2998   Certified                   3               0              2
# 3219   Certified                   1               0              2
#
#       FOREIGN_WORKER_INFO_EDUCATION_CODE  CLASS_OF_ADMISSION_CODE  \
# 1227                                   4                        3
# 1272                                   1                        3
# 2876                                   5                        3
# 2998                                   3                        3
# 3219                                   5                        5
#
#       CASE_RECEIVED_DATE_MONTH  EMPLOYER_REGIONS_CODE
# 1227                       9.0                      3
# 1272                       2.0                      2
# 2876                      11.0                      3
# 2998                       3.0                      3
# 3219                       6.0                      3

# %%
data7.dtypes
# Out:
# CASE_STATUS                            object
# EMPLOYEE_BINS_CODE                      int32
# WAGE_BINS_CODE                          int32
# DAY_BINS_CODE                           int32
# FOREIGN_WORKER_INFO_EDUCATION_CODE      int32
# CLASS_OF_ADMISSION_CODE                 int32
# CASE_RECEIVED_DATE_MONTH              float64
# EMPLOYER_REGIONS_CODE                   int32
# dtype: object

# %%
X = data7.drop("CASE_STATUS", axis=1)
y = data7["CASE_STATUS"]
print(X.shape, y.shape)
# Out:
# (260, 7) (260,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42, stratify=y)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=7))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=500,
    shuffle=True,
    verbose=2
)
# Out:
# WARNING:tensorflow:From C:\Users\kathleen.buckingham\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
#  - 1s - loss: